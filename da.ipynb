# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.preprocessing import OneHotEncoder
from scipy.sparse import hstack
import MeCab
import ipadic

# %%
df = pd.read_csv("./errors.csv")
df.head()
# Out:
#   Item.Description Item.Manufacturer Item.PartsNo 問題点.No     問題点.内容  \
# 0        サンプリングライン                C社     P-891516   P001      配管の亀裂
# 1              ポンプ                F社     P-689038   P002  腐食による機能不全
# 2            フィルター                D社     P-155322   P003      配管の亀裂
# 3              電磁弁                A社     P-426572   P004     制御盤が停止
# 4              圧力計                E社     P-889925   P005     制御盤が停止
#
#        問題点.原因    問題点.発覚日時     問題点.Project    対策.応急処置          対策.恒久対策
# 0     定期点検の不備  2025/07/12  塩素注入設備更新プロジェクト   フィルターの交換  材質を耐塩素性の高いものに変更
# 1       異物の混入  2025/07/25  塩素注入設備更新プロジェクト  漏れ箇所の部品交換     定期点検マニュアルの更新
# 2       異物の混入  2025/07/09  塩素注入設備更新プロジェクト   センサーの再校正  材質を耐塩素性の高いものに変更
# 3  締め付けトルクの不足  2025/07/25  塩素注入設備更新プロジェクト   詰まり箇所の洗浄     自動洗浄機能の導入を検討
# 4  締め付けトルクの不足  2025/07/30  塩素注入設備更新プロジェクト   センサーの再校正       防食・防湿処理を強化

# %%
df_X = df.drop(
    [
        "問題点.原因",
        "問題点.No",
        "対策.応急処置",
        "対策.恒久対策",
    ],
    axis=1,
)
df_y = df["問題点.原因"]

text_columns = [
    "Item.Description", 
    "問題点.内容",
]
categorical_columns = ["Item.Manufacturer", "Item.PartsNo", "問題点.Project"]

df_X.head()
# Out:
#   Item.Description Item.Manufacturer Item.PartsNo     問題点.内容    問題点.発覚日時  \
# 0        サンプリングライン                C社     P-891516      配管の亀裂  2025/07/12
# 1              ポンプ                F社     P-689038  腐食による機能不全  2025/07/25
# 2            フィルター                D社     P-155322      配管の亀裂  2025/07/09
# 3              電磁弁                A社     P-426572     制御盤が停止  2025/07/25
# 4              圧力計                E社     P-889925     制御盤が停止  2025/07/30
#
#       問題点.Project
# 0  塩素注入設備更新プロジェクト
# 1  塩素注入設備更新プロジェクト
# 2  塩素注入設備更新プロジェクト
# 3  塩素注入設備更新プロジェクト
# 4  塩素注入設備更新プロジェクト

# %%
X_train, X_test, y_train, y_test = train_test_split(
    df_X, df_y, test_size=0.2, random_state=42
)

print(f"学習データ数: {len(X_train)}")
print(f"テストデータ数: {len(X_test)}")
# Out:
# 学習データ数: 160
# テストデータ数: 40

# %%
def tokenize_text(text):
    tagger = MeCab.Tagger(f"-O wakati {ipadic.MECAB_ARGS}")
    return tagger.parse(text).strip()

# %%
tfidf_vectorizers = {}
X_tfidf_features = []

for col in text_columns:
    print(f"processing text column: {col}")
    cleaned_text = df_X[col].fillna("").apply(tokenize_text)
    vectorizer = TfidfVectorizer(min_df=1, max_df=0.9, ngram_range=(1, 2))
    X_tfidf_features.append(vectorizer.fit_transform(cleaned_text))
    tfidf_vectorizers[col] = vectorizer
# Out:
# processing text column: Item.Description
# processing text column: 問題点.内容

# %%
encoder = OneHotEncoder(handle_unknown="ignore", sparse_output=True)
X_categorical_features = encoder.fit_transform(df_X[categorical_columns])

print(f"カテゴリ特徴量の形状: {X_categorical_features.shape}")
# Out:
# カテゴリ特徴量の形状: (200, 207)

# %%
all_features = hstack(X_tfidf_features + [X_categorical_features])

print(f"結合された全特徴量の形状: {all_features.shape}")
# Out:
# 結合された全特徴量の形状: (200, 263)

# %%
X_train_combined, X_test_combined, y_train, y_test = train_test_split(
    all_features,
    df_y,
    test_size=0.2,
    random_state=42,
)

print(f"\n最終的な学習データ数: {X_train_combined.shape[0]}")
print(f"最終的なテストデータ数: {X_test_combined.shape[0]}")
# Out:
# 最終的な学習データ数: 160
# 最終的なテストデータ数: 40

# %%
model = SVC(kernel="linear", C=1.0, random_state=42)
model.fit(X_train_combined, y_train)
# Out:
# SVC(kernel='linear', random_state=42)

# %%
y_pred = model.predict(X_test_combined)

print(classification_report(y_test, y_pred, zero_division=0))
# Out:
#               precision    recall  f1-score   support
#
#    パッキンの経年劣化       0.00      0.00      0.00         3
#      塩素ガスの侵入       0.29      0.33      0.31         6
#    外的要因による損傷       0.14      0.25      0.18         4
#      定期点検の不備       0.00      0.00      0.00         7
#      水質変動の影響       0.25      0.20      0.22         5
#        異物の混入       0.00      0.00      0.00         1
#   締め付けトルクの不足       0.33      0.50      0.40         4
#      部品の初期不良       0.00      0.00      0.00         8
#     電源系統の不安定       0.00      0.00      0.00         2
#
#     accuracy                           0.15        40
#    macro avg       0.11      0.14      0.12        40
# weighted avg       0.12      0.15      0.13        40

# %%
y_pred_dec = model.decision_function(X_test_combined)
X_test_labels = X_test.reset_index().drop(["index"], axis=1)
class_labels = model.classes_
for i in range(len(y_pred_dec)):
    y_sorted = sorted(list(zip(class_labels, y_pred_dec[i])), key=lambda x: x[1], reverse=True)
    y_sorted = list(map(lambda x: (x[0], round(float(x[1]), 3)), y_sorted))
    print(X_test_labels.iloc[i])
    print(y_sorted[:3])
    print(y_test.iloc[i])
    print("------------------------------------------------------")
# Out:
# Item.Description                流量計
# Item.Manufacturer                B社
# Item.PartsNo               P-775529
# 問題点.内容                       制御盤が停止
# 問題点.発覚日時                 2025/07/02
# 問題点.Project          塩素注入設備更新プロジェクト
# Name: 0, dtype: object
# [('締め付けトルクの不足', 8.274), ('外的要因による損傷', 7.274), ('異物の混入', 6.27)]
# パッキンの経年劣化
# ------------------------------------------------------
# Item.Description              フィルター
# Item.Manufacturer                D社
# Item.PartsNo               P-998342
# 問題点.内容                      パッキンの劣化
# 問題点.発覚日時                 2025/07/05
# 問題点.Project          塩素注入設備更新プロジェクト
# Name: 1, dtype: object
# [('電源系統の不安定', 8.289), ('異物の混入', 6.252), ('塩素ガスの侵入', 6.226)]
# 外的要因による損傷
# ------------------------------------------------------
# Item.Description                逆止弁
# Item.Manufacturer                E社
# Item.PartsNo               P-756904
# 問題点.内容                      塩素漏れが発生
# 問題点.発覚日時                 2025/07/26
# 問題点.Project          塩素注入設備更新プロジェクト
# Name: 2, dtype: object
# [('外的要因による損傷', 8.29), ('塩素ガスの侵入', 7.278), ('締め付けトルクの不足', 5.257)]
# パッキンの経年劣化
# ------------------------------------------------------
# Item.Description                圧力計
# Item.Manufacturer                C社
# Item.PartsNo               P-635362
# 問題点.内容                       制御盤が停止
# 問題点.発覚日時                 2025/07/13
# 問題点.Project          塩素注入設備更新プロジェクト
# Name: 3, dtype: object
# [('締め付けトルクの不足', 8.293), ('電源系統の不安定', 7.286), ('パッキンの経年劣化', 4.906)]
# 塩素ガスの侵入
# ------------------------------------------------------
# Item.Description                逆止弁
# Item.Manufacturer                E社
# Item.PartsNo               P-797679
# 問題点.内容                   センサーが応答しない
# 問題点.発覚日時                 2025/07/26
# 問題点.Project          塩素注入設備更新プロジェクト
# Name: 4, dtype: object
# [('締め付けトルクの不足', 7.266), ('塩素ガスの侵入', 7.26), ('異物の混入', 7.204)]
# パッキンの経年劣化
# ------------------------------------------------------
# Item.Description              フィルター
# Item.Manufacturer                C社
# Item.PartsNo               P-459177
# 問題点.内容                        配管の亀裂
# 問題点.発覚日時                 2025/07/23
# 問題点.Project          塩素注入設備更新プロジェクト
# Name: 5, dtype: object
# [('水質変動の影響', 8.291), ('異物の混入', 6.251), ('定期点検の不備', 6.213)]
# 部品の初期不良
# ------------------------------------------------------
# Item.Description            インジェクター
# Item.Manufacturer                D社
# Item.PartsNo               P-198991
# 問題点.内容                      塩素漏れが発生
# 問題点.発覚日時                 2025/08/01
# 問題点.Project          塩素注入設備更新プロジェクト
# Name: 6, dtype: object
# [('塩素ガスの侵入', 8.296), ('締め付けトルクの不足', 7.271), ('外的要因による損傷', 5.257)]
# 塩素ガスの侵入
# ------------------------------------------------------
# Item.Description              配管接続部
# Item.Manufacturer                D社
# Item.PartsNo               P-483123
# 問題点.内容                   センサーが応答しない
# 問題点.発覚日時                 2025/07/10
# 問題点.Project          塩素注入設備更新プロジェクト
# Name: 7, dtype: object
# [('部品の初期不良', 8.294), ('塩素ガスの侵入', 6.274), ('電源系統の不安定', 6.269)]
# 塩素ガスの侵入
# ------------------------------------------------------
# Item.Description                 流量計
# Item.Manufacturer                 B社
# Item.PartsNo                P-470131
# 問題点.内容               詰まりが発生し、注入量が不安定
# 問題点.発覚日時                  2025/07/05
# 問題点.Project           塩素注入設備更新プロジェクト
# Name: 8, dtype: object
# [('異物の混入', 8.287), ('水質変動の影響', 6.241), ('電源系統の不安定', 6.241)]
# 塩素ガスの侵入
# ------------------------------------------------------
# Item.Description                ポンプ
# Item.Manufacturer                B社
# Item.PartsNo               P-980420
# 問題点.内容                      パッキンの劣化
# 問題点.発覚日時                 2025/07/09
# 問題点.Project          塩素注入設備更新プロジェクト
# Name: 9, dtype: object
# [('締め付けトルクの不足', 7.26), ('電源系統の不安定', 7.253), ('水質変動の影響', 7.253)]
# 水質変動の影響
# ------------------------------------------------------
# Item.Description          サンプリングライン
# Item.Manufacturer                F社
# Item.PartsNo               P-699399
# 問題点.内容                   センサーが応答しない
# 問題点.発覚日時                 2025/07/15
# 問題点.Project          塩素注入設備更新プロジェクト
# Name: 10, dtype: object
# [('パッキンの経年劣化', 8.286), ('部品の初期不良', 7.217), ('締め付けトルクの不足', 6.254)]
# 締め付けトルクの不足
# ------------------------------------------------------
# Item.Description            インジェクター
# Item.Manufacturer                B社
# Item.PartsNo               P-843306
# 問題点.内容                      塩素漏れが発生
# 問題点.発覚日時                 2025/07/29
# 問題点.Project          塩素注入設備更新プロジェクト
# Name: 11, dtype: object
# [('塩素ガスの侵入', 8.281), ('外的要因による損傷', 7.286), ('異物の混入', 6.241)]
# 外的要因による損傷
# ------------------------------------------------------
# Item.Description                ポンプ
# Item.Manufacturer                A社
# Item.PartsNo               P-346390
# 問題点.内容                       制御盤が停止
# 問題点.発覚日時                 2025/07/01
# 問題点.Project          塩素注入設備更新プロジェクト
# Name: 12, dtype: object
# [('締め付けトルクの不足', 8.299), ('外的要因による損傷', 7.286), ('異物の混入', 6.19)]
# 外的要因による損傷
# ------------------------------------------------------
# Item.Description                 流量計
# Item.Manufacturer                 D社
# Item.PartsNo                P-684169
# 問題点.内容               詰まりが発生し、注入量が不安定
# 問題点.発覚日時                  2025/07/03
# 問題点.Project           塩素注入設備更新プロジェクト
# Name: 13, dtype: object
# [('電源系統の不安定', 8.276), ('水質変動の影響', 7.264), ('異物の混入', 6.28)]
# 定期点検の不備
# ------------------------------------------------------
# Item.Description           塩素ボンベ接続部
# Item.Manufacturer                D社
# Item.PartsNo               P-193384
# 問題点.内容                   フィルターの目詰まり
# 問題点.発覚日時                 2025/07/31
# 問題点.Project          塩素注入設備更新プロジェクト
# Name: 14, dtype: object
# [('外的要因による損傷', 8.292), ('パッキンの経年劣化', 7.258), ('塩素ガスの侵入', 6.283)]
# 部品の初期不良
# ------------------------------------------------------
# Item.Description              フィルター
# Item.Manufacturer                B社
# Item.PartsNo               P-411548
# 問題点.内容                   センサーが応答しない
# 問題点.発覚日時                 2025/07/04
# 問題点.Project          塩素注入設備更新プロジェクト
# Name: 15, dtype: object
# [('部品の初期不良', 8.26), ('異物の混入', 7.283), ('電源系統の不安定', 6.238)]
# 塩素ガスの侵入
# ------------------------------------------------------
# Item.Description                流量計
# Item.Manufacturer                E社
# Item.PartsNo               P-468291
# 問題点.内容                        配管の亀裂
# 問題点.発覚日時                 2025/07/25
# 問題点.Project          塩素注入設備更新プロジェクト
# Name: 16, dtype: object
# [('締め付けトルクの不足', 8.285), ('定期点検の不備', 6.284), ('異物の混入', 6.244)]
# 締め付けトルクの不足
# ------------------------------------------------------
# Item.Description                制御盤
# Item.Manufacturer                A社
# Item.PartsNo               P-734572
# 問題点.内容                      パッキンの劣化
# 問題点.発覚日時                 2025/07/27
# 問題点.Project          塩素注入設備更新プロジェクト
# Name: 17, dtype: object
# [('締め付けトルクの不足', 7.278), ('外的要因による損傷', 7.273), ('塩素ガスの侵入', 6.277)]
# 電源系統の不安定
# ------------------------------------------------------
# Item.Description          サンプリングライン
# Item.Manufacturer                B社
# Item.PartsNo               P-709659
# 問題点.内容                        配管の亀裂
# 問題点.発覚日時                 2025/07/15
# 問題点.Project          塩素注入設備更新プロジェクト
# Name: 18, dtype: object
# [('塩素ガスの侵入', 7.267), ('定期点検の不備', 7.243), ('外的要因による損傷', 7.234)]
# 定期点検の不備
# ------------------------------------------------------
# Item.Description              フィルター
# Item.Manufacturer                B社
# Item.PartsNo               P-651900
# 問題点.内容                       制御盤が停止
# 問題点.発覚日時                 2025/07/21
# 問題点.Project          塩素注入設備更新プロジェクト
# Name: 19, dtype: object
# [('異物の混入', 8.292), ('電源系統の不安定', 7.233), ('締め付けトルクの不足', 6.226)]
# 水質変動の影響
# ------------------------------------------------------
# Item.Description                電磁弁
# Item.Manufacturer                C社
# Item.PartsNo               P-436143
# 問題点.内容                    腐食による機能不全
# 問題点.発覚日時                 2025/07/23
# 問題点.Project          塩素注入設備更新プロジェクト
# Name: 20, dtype: object
# [('電源系統の不安定', 8.291), ('部品の初期不良', 7.279), ('定期点検の不備', 5.218)]
# 定期点検の不備
# ------------------------------------------------------
# Item.Description                電磁弁
# Item.Manufacturer                C社
# Item.PartsNo               P-576997
# 問題点.内容                        配管の亀裂
# 問題点.発覚日時                 2025/08/02
# 問題点.Project          塩素注入設備更新プロジェクト
# Name: 21, dtype: object
# [('定期点検の不備', 8.285), ('水質変動の影響', 7.254), ('締め付けトルクの不足', 6.26)]
# 部品の初期不良
# ------------------------------------------------------
# Item.Description                逆止弁
# Item.Manufacturer                A社
# Item.PartsNo               P-882673
# 問題点.内容                   フィルターの目詰まり
# 問題点.発覚日時                 2025/07/13
# 問題点.Project          塩素注入設備更新プロジェクト
# Name: 22, dtype: object
# [('塩素ガスの侵入', 8.29), ('外的要因による損傷', 7.284), ('締め付けトルクの不足', 5.173)]
# 塩素ガスの侵入
# ------------------------------------------------------
# Item.Description                制御盤
# Item.Manufacturer                D社
# Item.PartsNo               P-969888
# 問題点.内容                   センサーが応答しない
# 問題点.発覚日時                 2025/07/18
# 問題点.Project          塩素注入設備更新プロジェクト
# Name: 23, dtype: object
# [('塩素ガスの侵入', 8.267), ('締め付けトルクの不足', 7.259), ('水質変動の影響', 5.18)]
# 水質変動の影響
# ------------------------------------------------------
# Item.Description              配管接続部
# Item.Manufacturer                B社
# Item.PartsNo               P-509726
# 問題点.内容                       電磁弁の固着
# 問題点.発覚日時                 2025/07/12
# 問題点.Project          塩素注入設備更新プロジェクト
# Name: 24, dtype: object
# [('部品の初期不良', 8.302), ('パッキンの経年劣化', 7.228), ('塩素ガスの侵入', 5.221)]
# 水質変動の影響
# ------------------------------------------------------
# Item.Description                流量計
# Item.Manufacturer                F社
# Item.PartsNo               P-101752
# 問題点.内容                        配管の亀裂
# 問題点.発覚日時                 2025/07/19
# 問題点.Project          塩素注入設備更新プロジェクト
# Name: 25, dtype: object
# [('水質変動の影響', 8.278), ('締め付けトルクの不足', 7.283), ('異物の混入', 6.267)]
# 定期点検の不備
# ------------------------------------------------------
# Item.Description                ポンプ
# Item.Manufacturer                A社
# Item.PartsNo               P-673037
# 問題点.内容                       制御盤が停止
# 問題点.発覚日時                 2025/07/13
# 問題点.Project          塩素注入設備更新プロジェクト
# Name: 26, dtype: object
# [('締め付けトルクの不足', 8.299), ('外的要因による損傷', 7.286), ('異物の混入', 6.19)]
# 電源系統の不安定
# ------------------------------------------------------
# Item.Description                制御盤
# Item.Manufacturer                E社
# Item.PartsNo               P-206975
# 問題点.内容                      塩素漏れが発生
# 問題点.発覚日時                 2025/07/10
# 問題点.Project          塩素注入設備更新プロジェクト
# Name: 27, dtype: object
# [('外的要因による損傷', 8.299), ('塩素ガスの侵入', 6.281), ('締め付けトルクの不足', 6.28)]
# 外的要因による損傷
# ------------------------------------------------------
# Item.Description              フィルター
# Item.Manufacturer                E社
# Item.PartsNo               P-626373
# 問題点.内容                   フィルターの目詰まり
# 問題点.発覚日時                 2025/07/24
# 問題点.Project          塩素注入設備更新プロジェクト
# Name: 28, dtype: object
# [('異物の混入', 7.28), ('外的要因による損傷', 7.278), ('塩素ガスの侵入', 7.267)]
# 水質変動の影響
# ------------------------------------------------------
# Item.Description                流量計
# Item.Manufacturer                D社
# Item.PartsNo               P-639637
# 問題点.内容                      パッキンの劣化
# 問題点.発覚日時                 2025/07/06
# 問題点.Project          塩素注入設備更新プロジェクト
# Name: 29, dtype: object
# [('電源系統の不安定', 8.277), ('塩素ガスの侵入', 7.25), ('水質変動の影響', 6.21)]
# 異物の混入
# ------------------------------------------------------
# Item.Description          サンプリングライン
# Item.Manufacturer                C社
# Item.PartsNo               P-117811
# 問題点.内容                       電磁弁の固着
# 問題点.発覚日時                 2025/07/06
# 問題点.Project          塩素注入設備更新プロジェクト
# Name: 30, dtype: object
# [('部品の初期不良', 8.285), ('定期点検の不備', 7.224), ('締め付けトルクの不足', 6.246)]
# 定期点検の不備
# ------------------------------------------------------
# Item.Description                電磁弁
# Item.Manufacturer                C社
# Item.PartsNo               P-668114
# 問題点.内容                   フィルターの目詰まり
# 問題点.発覚日時                 2025/07/12
# 問題点.Project          塩素注入設備更新プロジェクト
# Name: 31, dtype: object
# [('外的要因による損傷', 7.273), ('電源系統の不安定', 7.237), ('締め付けトルクの不足', 6.217)]
# 部品の初期不良
# ------------------------------------------------------
# Item.Description                ポンプ
# Item.Manufacturer                C社
# Item.PartsNo               P-829418
# 問題点.内容                      塩素漏れが発生
# 問題点.発覚日時                 2025/07/27
# 問題点.Project          塩素注入設備更新プロジェクト
# Name: 32, dtype: object
# [('水質変動の影響', 7.283), ('締め付けトルクの不足', 6.282), ('定期点検の不備', 6.261)]
# 部品の初期不良
# ------------------------------------------------------
# Item.Description               フィルター
# Item.Manufacturer                 A社
# Item.PartsNo                P-764074
# 問題点.内容               詰まりが発生し、注入量が不安定
# 問題点.発覚日時                  2025/07/19
# 問題点.Project           塩素注入設備更新プロジェクト
# Name: 33, dtype: object
# [('異物の混入', 8.299), ('電源系統の不安定', 7.279), ('水質変動の影響', 6.257)]
# 定期点検の不備
# ------------------------------------------------------
# Item.Description              配管接続部
# Item.Manufacturer                C社
# Item.PartsNo               P-875098
# 問題点.内容                   センサーが応答しない
# 問題点.発覚日時                 2025/07/18
# 問題点.Project          塩素注入設備更新プロジェクト
# Name: 34, dtype: object
# [('部品の初期不良', 8.305), ('電源系統の不安定', 7.269), ('塩素ガスの侵入', 4.869)]
# 定期点検の不備
# ------------------------------------------------------
# Item.Description              配管接続部
# Item.Manufacturer                E社
# Item.PartsNo               P-604474
# 問題点.内容                        配管の亀裂
# 問題点.発覚日時                 2025/07/28
# 問題点.Project          塩素注入設備更新プロジェクト
# Name: 35, dtype: object
# [('定期点検の不備', 8.275), ('塩素ガスの侵入', 7.287), ('外的要因による損傷', 6.233)]
# 部品の初期不良
# ------------------------------------------------------
# Item.Description                電磁弁
# Item.Manufacturer                D社
# Item.PartsNo               P-494975
# 問題点.内容                      塩素漏れが発生
# 問題点.発覚日時                 2025/07/09
# 問題点.Project          塩素注入設備更新プロジェクト
# Name: 36, dtype: object
# [('外的要因による損傷', 8.272), ('電源系統の不安定', 6.268), ('締め付けトルクの不足', 6.224)]
# 部品の初期不良
# ------------------------------------------------------
# Item.Description                流量計
# Item.Manufacturer                A社
# Item.PartsNo               P-910460
# 問題点.内容                       電磁弁の固着
# 問題点.発覚日時                 2025/07/29
# 問題点.Project          塩素注入設備更新プロジェクト
# Name: 37, dtype: object
# [('締め付けトルクの不足', 8.285), ('異物の混入', 7.263), ('塩素ガスの侵入', 5.209)]
# 締め付けトルクの不足
# ------------------------------------------------------
# Item.Description                 流量計
# Item.Manufacturer                 F社
# Item.PartsNo                P-853036
# 問題点.内容               詰まりが発生し、注入量が不安定
# 問題点.発覚日時                  2025/07/17
# 問題点.Project           塩素注入設備更新プロジェクト
# Name: 38, dtype: object
# [('電源系統の不安定', 8.279), ('異物の混入', 7.294), ('水質変動の影響', 6.269)]
# 部品の初期不良
# ------------------------------------------------------
# Item.Description                ポンプ
# Item.Manufacturer                B社
# Item.PartsNo               P-594786
# 問題点.内容                       制御盤が停止
# 問題点.発覚日時                 2025/07/27
# 問題点.Project          塩素注入設備更新プロジェクト
# Name: 39, dtype: object
# [('外的要因による損傷', 8.286), ('締め付けトルクの不足', 7.285), ('異物の混入', 5.206)]
# 締め付けトルクの不足
# ------------------------------------------------------
